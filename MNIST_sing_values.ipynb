# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
with open('singular_values.pkl', 'rb') as f:
    singular_values = pickle.load(f)

# %%
print(np.flip(singular_values)[:10])
# Out:
# [15.76428174  4.67895649  3.9086545   2.43095182  2.20432607  2.14280932
#   2.0688307   1.84479215  1.7683712   1.72080748]

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.flip(singular_values), linestyle='-', color='coral', label='Singular Values')

# Enhancements
plt.title('Singular Values of MNIST', fontsize=16, fontweight='bold')
plt.xlabel('Index', fontsize=14)
plt.ylabel('Value', fontsize=14)
plt.yscale('log')  # Use log scale if the range is large
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=12)

# Show the plot
plt.tight_layout()
plt.savefig('EPFL/HPC/project2/plots/singular_values_MNIST.png')
plt.show()
